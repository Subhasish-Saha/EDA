# %% [markdown]
# #FIFA DATA ANALYSIS

# %%
#loading the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
fifa = pd.read_csv('/content/drive/MyDrive/DATASETS/players_20.csv') #loading the dataset
fifa
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# ...          ...                                                ...  ...   ...   ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...  ...  46+2  45+2
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...  ...  47+2  46+2
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...  ...  49+2  47+2
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...  ...  49+2  48+2
# ...

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
#
# [5 rows x 104 columns]

# %%
for col in fifa.columns:   #viewing all the columns name
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
#finding the number of players with same nationality
fifa['nationality'].value_counts()
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
#              ...
# Indonesia       1
# Jordan          1
# Mauritius       1
# Vietnam         1
# Hong Kong       1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]  #top 10 countries with highest players
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10].keys() #name of the top 10 countries with highest number of players
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
#plotting a bar plot depicting the top 5 countries with number of players 
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color = "orange")
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']] #extracting name of a player and his salary

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
#sorting salary of players in ascending order
player_salary = player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
#plotting bar plot with respect to the salary of the players
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color = {'blue','green','red','pink','orange'})
plt.show()

# %%
fifa['nationality']=='Germany' #checking if players are from germany(nationality)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
#findng players from germany
Germany = fifa[fifa['nationality']=='Germany']
Germany.head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...  ...   NaN   NaN
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...  ...  55+3  64+3
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...  ...  84+3  78+3
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...  ...  43+2  44+2
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...  ...  47+2  39+2
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...  ...  83+2  75+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...  ...  52+2  61+2
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...  ...  72+3  74+3
# 70      189596  https://sofifa.com/player/189596/thomas-muller...  ...  62+3  67+3
#
# [5 rows x 104 columns]

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
#shooting
player_shooting= fifa[['short_name','shooting']]

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#defending
player_defending= fifa[['short_name','defending','nationality','club']]
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
fcb = fifa[fifa['club']=='FC Barcelona']

# %%
fcb.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 22     194765  https://sofifa.com/player/194765/antoine-griez...  ...  65+3  70+3
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...  ...  63+5  64+5
# 21     189511  https://sofifa.com/player/189511/sergio-busque...  ...  82+3  78+3
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...  ...  85+3  78+3
#
# [5 rows x 104 columns]

# %%
fcb.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 0       158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 19      176580  https://sofifa.com/player/176580/luis-suarez/2...  ...  63+5  64+5
# 22      194765  https://sofifa.com/player/194765/antoine-griez...  ...  65+3  70+3
# 64      168651  https://sofifa.com/player/168651/ivan-rakitic/...  ...  72+3  75+3
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...  ...  84+3  82+3
#
# [5 rows x 104 columns]

# %%
fcb.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 29      152729  https://sofifa.com/player/152729/gerard-pique-...  ...  85+3  78+3
# 84      220440  https://sofifa.com/player/220440/clement-lengl...  ...  83+2  79+2
# 59      205600  https://sofifa.com/player/205600/samuel-umtiti...  ...  84+3  79+3
# 21      189511  https://sofifa.com/player/189511/sergio-busque...  ...  82+3  78+3
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...  ...  84+3  82+3
#
# [5 rows x 104 columns]

# %%
fcb['nationality'].value_counts()
# Out:
# Spain          15
# France          5
# Brazil          3
# Netherlands     2
# Argentina       1
# Croatia         1
# Germany         1
# Portugal        1
# Uruguay         1
# Japan           1
# Chile           1
# Senegal         1
# Name: nationality, dtype: int64
